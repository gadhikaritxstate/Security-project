# %%
# anomaly detection module
from pycaret.anomaly import *
import pandas as pd
import numpy as np

df=pd.read_csv('./data/CICIDS2017_sample.csv')
X = df.drop(['Label'],axis=1).values
y = df.iloc[:, -1].values.reshape(-1,1)
y=np.ravel(y)

# %%
X
# Out:
# array([[4.0000000e+00, 2.0000000e+00, 0.0000000e+00, ..., 0.0000000e+00,
#         0.0000000e+00, 0.0000000e+00],
#        [1.4237700e+05, 4.6000000e+01, 6.2000000e+01, ..., 0.0000000e+00,
#         0.0000000e+00, 0.0000000e+00],
#        [1.1887300e+05, 2.3000000e+01, 2.8000000e+01, ..., 0.0000000e+00,
#         0.0000000e+00, 0.0000000e+00],
#        ...,
#        [1.1507694e+07, 5.0000000e+00, 4.0000000e+00, ..., 0.0000000e+00,
#         6.5036400e+06, 6.5036400e+06],
#        [1.1507707e+07, 8.0000000e+00, 6.0000000e+00, ..., 0.0000000e+00,
#         6.5031220e+06, 6.5031220e+06],
#        [1.1512204e+07, 8.0000000e+00, 5.0000000e+00, ..., 0.0000000e+00,
#         6.5071970e+06, 6.5071970e+06]])

# %%
df
# Out:
#        Flow Duration  Total Fwd Packets  Total Backward Packets  \
# 0                  4                  2                       0
# 1             142377                 46                      62
# 2             118873                 23                      28
# 3             143577                 43                      55
# 4             143745                 49                      59
# ...              ...                ...                     ...
# 56656            234                  2                       2
# 56657         133288                  2                       2
# 56658       11507694                  5                       4
# 56659       11507707                  8                       6
# 56660       11512204                  8                       5
#
#        Total Length of Fwd Packets  Total Length of Bwd Packets  \
# 0                               37                            0
# 1                             1325                       105855
# 2                             1169                        45025
# 3                             1301                       107289
# 4                             1331                       110185
# ...                            ...                          ...
# 56656                           64                          232
# 56657                           94                          482
# 56658                          450                         3525
# 56659                          416                        11632
# 56660                          326                        11632
#
#        Fwd Packet Length Max  Fwd Packet Length Min  Fwd Packet Length Mean  \
# 0                         31                      6               18.500000
# 1                        570                      0               28.804348
# 2                        570                      0               50.826087
# 3                        570                      0               30.255814
# 4                        570                      0               27.163265
# ...                      ...                    ...                     ...
# 56656                     32                     32               32.000000
# 56657                     47                     47               47.000000
# 56658                    450                      0               90.000000
# 56659                    416                      0               52.000000
# 56660                    326                      0               40.750000
#
#        Fwd Packet Length Std  Bwd Packet Length Max  ...  \
# 0                  17.677670                      0  ...
# 1                 111.407285                   4344  ...
# 2                 156.137367                   2896  ...
# 3                 115.178969                   4344  ...
# 4                 108.067176                   4344  ...
# ...                      ...                    ...  ...
# 56656               0.000000                    116  ...
# 56657               0.000000                    241  ...
# 56658             201.246118                   3525  ...
# 56659             147.078211                   5792  ...
# 56660             115.258405                  10184  ...
#
#        min_seg_size_forward  Active Mean  Active Std  Active Max  Active Min  \
# 0                        20          0.0         0.0           0           0
# 1                        20          0.0         0.0           0           0
# 2                        32          0.0         0.0           0           0
# 3                        20          0.0         0.0           0           0
# 4                        20          0.0         0.0           0           0
# ...                     ...          ...         ...         ...         ...
# 56656                    32          0.0         0.0           0           0
# 56657                    32          0.0         0.0           0           0
# 56658                    32        893.0         0.0         893         893
# 56659                    32        897.0         0.0         897         897
# 56660                    32        892.0         0.0         892         892
#
#        Idle Mean  Idle Std  Idle Max  Idle Min   Label
# 0            0.0       0.0         0         0  BENIGN
# 1            0.0       0.0         0         0  BENIGN
# 2            0.0       0.0         0         0  BENIGN
# 3            0.0       0.0         0         0  BENIGN
# 4            0.0       0.0         0         0  BENIGN
# ...          ...       ...       ...       ...     ...
# 56656        0.0       0.0         0         0  BENIGN
# 56657        0.0       0.0         0         0  BENIGN
# 56658  6503640.0       0.0   6503640   6503640     DoS
# 56659  6503122.0       0.0   6503122   6503122     DoS
# 56660  6507197.0       0.0   6507197   6507197     DoS
#
# [56661 rows x 78 columns]

# %%
y
# Out:
# array(['BENIGN', 'BENIGN', 'BENIGN', ..., 'DoS', 'DoS', 'DoS'],
#       dtype=object)

# %%
from pycaret.anomaly import *
## init the setup
exp = setup(df, ignore_features=['Flow Bytes '])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[14], line 3
#       1 from pycaret.anomaly import *
#       2 ## init the setup
# ----> 3 exp = setup(df, ignore_features=['Flow Bytes'])
#
# File C:\Anaconda\envs\sec_proj_env\lib\site-packages\pycaret\anomaly\functional.py:442, in setup(data, data_func, index, ordinal_features, numeric_features, categorical_features, date_features, text_features, ignore_features, keep_features, preprocess, create_date_columns, imputation_type, numeric_imputation, categorical_imputation, text_features_method, max_encoding_ohe, encoding_method, rare_to_value, rare_value, polynomial_features, polynomial_degree, low_variance_threshold, group_features, drop_groups, remove_multicollinearity, multicollinearity_threshold, bin_numeric_features, remove_outliers, outliers_method, outliers_threshold, transformation, transformation_method, normalize, normalize_method, pca, pca_method, pca_components, custom_pipeline, custom_pipeline_position, n_jobs, use_gpu, html, session_id, system_log, log_experiment, experiment_name, experiment_custom_tags, log_plots, log_profile, log_data, verbose, memory, profile, profile_kwargs)
#     440 exp = _EXPERIMENT_CLASS()
#     441 set_current_experiment(exp)
# --> 442 return exp.setup(
#     443     data=data,
#     444     data_func=data_func,
#     445     index=index,
#     446     ordinal_features=ordinal_features,
#     447     numeric_features=numeric_features,
#     448     categorical_features=categorical_features,
#     449     date_features=date_features,
#     450     text_features=text_features,
#     451     ignore_features=ignore_features,
#     452     keep_features=keep_features,
#     453     preprocess=preprocess,
#     454     create_date_columns=create_date_columns,
#     455     imputation_type=imputation_type,
#     456     numeric_imputation=numeric_imputation,
#     457     categorical_imputation=categorical_imputation,
#     458     text_features_method=text_features_method,
#     459     max_encoding_ohe=max_encoding_ohe,
#     460     encoding_method=encoding_method,
#     461     rare_to_value=rare_to_value,
#     462     rare_value=rare_value,
#     463     polynomial_features=polynomial_features,
#     464     polynomial_degree=polynomial_degree,
#     465     low_variance_threshold=low_variance_threshold,
#     466     group_features=group_features,
#     467     drop_groups=drop_groups,
#     468     remove_multicollinearity=remove_multicollinearity,
#     469     multicollinearity_threshold=multicollinearity_threshold,
#     470     bin_numeric_features=bin_numeric_features,
#     471     remove_outliers=remove_outliers,
#     472     outliers_method=outliers_method,
#     473     outliers_threshold=outliers_threshold,
#     474     transformation=transformation,
#     475     transformation_method=transformation_method,
#     476     normalize=normalize,
#     477     normalize_method=normalize_method,
#     478     pca=pca,
#     479     pca_method=pca_method,
#     480     pca_components=pca_components,
#     481     custom_pipeline=custom_pipeline,
#     482     custom_pipeline_position=custom_pipeline_position,
#     483     n_jobs=n_jobs,
#     484     use_gpu=use_gpu,
#     485     html=html,
#     486     session_id=session_id,
#     487     system_log=system_log,
#     488     log_experiment=log_experiment,
#     489     experiment_name=experiment_name,
#     490     experiment_custom_tags=experiment_custom_tags,
#     491     log_plots=log_plots,
#     492     log_profile=log_profile,
#     493     log_data=log_data,
#     494     verbose=verbose,
#     495     memory=memory,
#     496     profile=profile,
#     497     profile_kwargs=profile_kwargs,
#     498 )
#
# File C:\Anaconda\envs\sec_proj_env\lib\site-packages\pycaret\internal\pycaret_experiment\unsupervised_experiment.py:651, in _UnsupervisedExperiment.setup(self, data, data_func, index, ordinal_features, numeric_features, categorical_features, date_features, text_features, ignore_features, keep_features, preprocess, create_date_columns, imputation_type, numeric_imputation, categorical_imputation, text_features_method, max_encoding_ohe, encoding_method, rare_to_value, rare_value, polynomial_features, polynomial_degree, low_variance_threshold, group_features, drop_groups, remove_multicollinearity, multicollinearity_threshold, bin_numeric_features, remove_outliers, outliers_method, outliers_threshold, transformation, transformation_method, normalize, normalize_method, pca, pca_method, pca_components, custom_pipeline, custom_pipeline_position, n_jobs, use_gpu, html, session_id, system_log, log_experiment, experiment_name, experiment_custom_tags, log_plots, log_profile, log_data, verbose, memory, profile, profile_kwargs, engines)
#     648 if ("placeholder", None) in self.pipeline.steps and len(self.pipeline) > 1:
#     649     self.pipeline.steps.remove(("placeholder", None))
# --> 651 self.pipeline.fit(self.X)
#     653 self.logger.info("Finished creating preprocessing pipeline.")
#     654 self.logger.info(f"Pipeline: {self.pipeline}")
#
# File C:\Anaconda\envs\sec_proj_env\lib\site-packages\pycaret\internal\pipeline.py:262, in Pipeline.fit(self, X, y, **fit_params)
#     260 def fit(self, X=None, y=None, **fit_params):
#     261     fit_params_steps = self._check_fit_params(**fit_params)
# --> 262     X, y, _ = self._fit(X, y, **fit_params_steps)
#     264     with _print_elapsed_time("Pipeline", self._log_message(len(self.steps) - 1)):
#     265         if self._final_estimator != "passthrough":
#
# File C:\Anaconda\envs\sec_proj_env\lib\site-packages\pycaret\internal\pipeline.py:238, in Pipeline._fit(self, X, y, **fit_params_steps)
#     235         cloned._cache_full_transform = False
#     237     # Fit or load the current transformer from cache
# --> 238     fitted_transformer = self._memory_fit(
#     239         transformer=cloned,
#     240         X=X,
#     241         y=y,
#     242         message=self._log_message(step_idx),
#     243         **fit_params_steps.get(name, {}),
#     244     )
#     245     X, y = self._memory_transform(
#     246         transformer=fitted_transformer,
#     247         X=X,
#     248         y=y,
#     249     )
#     251 # Replace the transformer of the step with the fitted
#     252 # transformer (necessary when loading from the cache)
#
# File C:\Anaconda\envs\sec_proj_env\lib\site-packages\joblib\memory.py:655, in MemorizedFunc.__call__(self, *args, **kwargs)
#     654 def __call__(self, *args, **kwargs):
# --> 655     return self._cached_call(args, kwargs)[0]
#
# File C:\Anaconda\envs\sec_proj_env\lib\site-packages\pycaret\internal\memory.py:398, in FastMemorizedFunc._cached_call(self, args, kwargs, shelving)
#     395 if must_call:
#     396     # PYCARET CHANGES
#     397     self._cached_output_identifiers = func_id, args_id
# --> 398     out, metadata = self.call(*args, **kwargs)
#     399     if self.mmap_mode is not None and metadata is not None:
#     400         # PYCARET CHANGES END
#     401         # Memmap the output at the first call to be consistent with
#     402         # later calls
#     403         if self._verbose:
#
# File C:\Anaconda\envs\sec_proj_env\lib\site-packages\pycaret\internal\memory.py:309, in FastMemorizedFunc.call(self, *args, **kwargs)
#     307 # PYCARET CHANGES
#     308 func_start_time = time.monotonic()
# --> 309 output = self.func(*args, **kwargs)
#     310 func_duration = time.monotonic() - func_start_time
#     311 if func_duration >= self.min_time_to_cache:
#
# File C:\Anaconda\envs\sec_proj_env\lib\site-packages\pycaret\internal\pipeline.py:66, in _fit_one(transformer, X, y, message, **fit_params)
#      64         if "y" in signature(transformer.fit).parameters:
#      65             args.append(y)
# ---> 66         transformer.fit(*args, **fit_params)
#      67 return transformer
#
# File C:\Anaconda\envs\sec_proj_env\lib\site-packages\pycaret\internal\preprocess\transformers.py:229, in TransformerWrapper.fit(self, X, y, **fit_params)
#     226 if "y" in transformer_params and y is not None:
#     227     args.append(y)
# --> 229 self.transformer.fit(*args, **fit_params)
#     230 return self
#
# File C:\Anaconda\envs\sec_proj_env\lib\site-packages\sklearn\impute\_base.py:390, in SimpleImputer.fit(self, X, y)
#     381 if self.verbose != "deprecated":
#     382     warnings.warn(
#     383         "The 'verbose' parameter was deprecated in version "
#     384         "1.1 and will be removed in 1.3. A warning will "
#    (...)
#     387         FutureWarning,
#     388     )
# --> 390 X = self._validate_input(X, in_fit=True)
#     392 # default fill_value is 0 for numerical input and "missing_value"
#     393 # otherwise
#     394 if self.fill_value is None:
#
# File C:\Anaconda\envs\sec_proj_env\lib\site-packages\sklearn\impute\_base.py:344, in SimpleImputer._validate_input(self, X, in_fit)
#     342         raise new_ve from None
#     343     else:
# --> 344         raise ve
#     346 if in_fit:
#     347     # Use the dtype seen in `fit` for non-`fit` conversion
#     348     self._fit_dtype = X.dtype
#
# File C:\Anaconda\envs\sec_proj_env\lib\site-packages\sklearn\impute\_base.py:327, in SimpleImputer._validate_input(self, X, in_fit)
#     324     force_all_finite = True
#     326 try:
# --> 327     X = self._validate_data(
#     328         X,
#     329         reset=in_fit,
#     330         accept_sparse="csc",
#     331         dtype=dtype,
#     332         force_all_finite=force_all_finite,
#     333         copy=self.copy,
#     334     )
#     335 except ValueError as ve:
#     336     if "could not convert" in str(ve):
#
# File C:\Anaconda\envs\sec_proj_env\lib\site-packages\sklearn\base.py:565, in BaseEstimator._validate_data(self, X, y, reset, validate_separately, **check_params)
#     563     raise ValueError("Validation should be done on X, y or both.")
#     564 elif not no_val_X and no_val_y:
# --> 565     X = check_array(X, input_name="X", **check_params)
#     566     out = X
#     567 elif no_val_X and not no_val_y:
#
# File C:\Anaconda\envs\sec_proj_env\lib\site-packages\sklearn\utils\validation.py:921, in check_array(array, accept_sparse, accept_large_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, ensure_min_samples, ensure_min_features, estimator, input_name)
#     915         raise ValueError(
#     916             "Found array with dim %d. %s expected <= 2."
#     917             % (array.ndim, estimator_name)
#     918         )
#     920     if force_all_finite:
# --> 921         _assert_all_finite(
#     922             array,
#     923             input_name=input_name,
#     924             estimator_name=estimator_name,
#     925             allow_nan=force_all_finite == "allow-nan",
#     926         )
#     928 if ensure_min_samples > 0:
#     929     n_samples = _num_samples(array)
#
# File C:\Anaconda\envs\sec_proj_env\lib\site-packages\sklearn\utils\validation.py:161, in _assert_all_finite(X, allow_nan, msg_dtype, estimator_name, input_name)
#     144 if estimator_name and input_name == "X" and has_nan_error:
#     145     # Improve the error message on how to handle missing values in
#     146     # scikit-learn.
#     147     msg_err += (
#     148         f"\n{estimator_name} does not accept missing values"
#     149         " encoded as NaN natively. For supervised learning, you might want"
#    (...)
#     159         "#estimators-that-handle-nan-values"
#     160     )
# --> 161 raise ValueError(msg_err)
#
# ValueError: Input X contains infinity or a value too large for dtype('float64').
